# %%
import matplotlib as mp

# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
x= np.linspace(0,4*np.pi,100)
plt.title("Waves")
plt.plot(x,np.sin(x), label="Sine")
plt.plot(x,np.cos(x), label="Cos")
plt.legend(loc='upper right')
plt.show()

# %%
x= np.linspace(0,4*np.pi,100)
plt.title("Waves style")

plt.plot(x,np.sin(x), label="Sine",ls=':')
plt.plot(x,np.cos(x), label="Cos",ls ='--')
plt.legend(loc='upper right')
plt.show()

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
plt.figure(figsize=(18,5))
plt.style.use('seaborn-v0_8-darkgrid')
x= np.linspace(0,4*np.pi,100)
plt.title("Waves")
plt.plot(x,np.sin(x), label="Sine")
plt.plot(x,np.cos(x), label="Cos")
plt.legend(loc='upper right')
plt.show()
wave=plt.figure()
wave.savefig('Waves1.png')

# %%
from IPython.display import Image
Image('Waves1.png')

# %% [markdown]
# different type of plots

# %%
plt.figure(figsize=(18,5))
plt.style.use('Solarize_Light2')
x= np.linspace(0,4*np.pi,100)
plt.title("Waves")
plt.plot(x,np.sin(x),c='r',linewidth=5, label="Sine")
plt.plot(x,np.cos(x),c='b',linewidth=2,label="Cos")
plt.legend(loc='upper right')
plt.show()

# %%
data=pd.read_csv('concrete.csv')
data
# Out:
#       cement   slag    ash  water  superplasticizer  coarseagg  fineagg  age  \
# 0      141.3  212.0    0.0  203.5               0.0      971.8    748.5   28
# 1      168.9   42.2  124.3  158.3              10.8     1080.8    796.2   14
# 2      250.0    0.0   95.7  187.4               5.5      956.9    861.2   28
# 3      266.0  114.0    0.0  228.0               0.0      932.0    670.0   28
# 4      154.8  183.4    0.0  193.3               9.1     1047.4    696.7   28
# ...      ...    ...    ...    ...               ...        ...      ...  ...
# 1025   135.0    0.0  166.0  180.0              10.0      961.0    805.0   28
# 1026   531.3    0.0    0.0  141.8              28.2      852.1    893.7    3
# 1027   276.4  116.0   90.3  179.6               8.9      870.1    768.3   28
# 1028   342.0   38.0    0.0  228.0               0.0      932.0    670.0  270
# 1029   540.0    0.0    0.0  173.0               0.0     1125.0    613.0    7
#
#       strength
# 0        29.89
# ...

# %%
s=data['strength']
w=data['water']
c=data['cement']

# %%
print(s.max(),s.min())
print(w.max(),w.min())
print(c.max(),c.min())
# Out:
# 82.6 2.33
# 247.0 121.8
# 540.0 102.0

# %% [markdown]
# single line graph

# %%
plt.figure(figsize=(50,10))
plt.style.use('dark_background')
plt.plot(s[:200],c='r',linewidth=5, label="Strength")
plt.show()

# %% [markdown]
# xlim, y lim

# %%
x=np.linspace(1,20,100)
plt.style.use('Solarize_Light2')
plt.xlim([0,25])
plt.ylim([-2,2])
plt.plot(x,np.sin(x))
plt.show()

# %%
x=np.linspace(1,20,100)
plt.style.use('Solarize_Light2')
plt.axis('equal') #or aixs('tight')
plt.plot(x,np.sin(x))
plt.show()

# %% [markdown]
# scatter plot

# %%
n=1000
x=np.random.randn(n)
y=np.random.randn(n)

plt.scatter(x,y,c='r',alpha=0.5,s=15)
plt.title("Scatter Plot")
plt.show()

# %%
n=1000
x1=np.random.randn(n)
y1=np.random.randn(n)

x2=np.random.randn(n)+2
y2=np.random.randn(n)+2

plt.style.use('seaborn-v0_8-darkgrid')
plt.scatter(x1,y1,c='r',alpha=0.7,s=15)
plt.scatter(x2,y2,c='b',alpha=0.7,s=15)
plt.title("Scatter Plot")
plt.show()

# %%
plt.scatter(s,c,c='g',alpha=0.7,s=20)
plt.title("Strength VS Cement")
plt.xlabel('Strength')
plt.ylabel('Cement')
# Out:
# Text(0, 0.5, 'Cement')

# %%
plt.scatter(s,c,c='g',alpha=0.7,s=50,marker='x')
plt.title("Strength VS Cement")
plt.xlabel('Strength')
plt.ylabel('Cement')
# Out:
# Text(0, 0.5, 'Cement')

# %%
from matplotlib import colormaps

# %%
for i in list(colormaps):
    print(i)
# Out:
# magma
# inferno
# plasma
# viridis
# cividis
# twilight
# twilight_shifted
# turbo
# Blues
# BrBG
# BuGn
# BuPu
# CMRmap
# GnBu
# Greens
# Greys
# OrRd
# Oranges
# PRGn
# PiYG
# PuBu
# PuBuGn
# PuOr
# PuRd
# Purples
# RdBu
# RdGy
# RdPu
# RdYlBu
# RdYlGn
# Reds
# Spectral
# Wistia
# YlGn
# YlGnBu
# YlOrBr
# YlOrRd
# afmhot
# autumn
# binary
# bone
# brg
# bwr
# cool
# coolwarm
# copper
# cubehelix
# flag
# gist_earth
# gist_gray
# gist_heat
# gist_ncar
# gist_rainbow
# gist_stern
# gist_yarg
# gnuplot
# gnuplot2
# gray
# hot
# hsv
# jet
# nipy_spectral
# ocean
# pink
# prism
# rainbow
# seismic
# spring
# summer
# terrain
# winter
# Accent
# Dark2
# Paired
# Pastel1
# Pastel2
# Set1
# Set2
# Set3
# tab10
# tab20
# tab20b
# tab20c
# magma_r
# inferno_r
# plasma_r
# viridis_r
# cividis_r
# twilight_r
# twilight_shifted_r
# turbo_r
# Blues_r
# BrBG_r
# BuGn_r
# BuPu_r
# CMRmap_r
# GnBu_r
# Greens_r
# Greys_r
# OrRd_r
# Oranges_r
# PRGn_r
# PiYG_r
# PuBu_r
# PuBuGn_r
# PuOr_r
# PuRd_r
# ...

# %%
rng=np.random.RandomState(0)
x=rng.randn(100)
y=rng.randn(100)
colors=rng.randn(100)
size=rng.randn(100)*1000
plt.scatter(x,y,c=colors,s=size,alpha=0.7,cmap='autumn',edgecolors='black')
plt.title('Random')
plt.colorbar()
plt.show()
# Out:
# /Users/chinmay/anaconda3/lib/python3.11/site-packages/matplotlib/collections.py:963: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
rng = np.random.RandomState(0)

x = rng.randn(100)
y = rng.randn(100)

colors = rng.rand(100)
sizes  = rng.rand(100) * 1000

plt.scatter(x,y, c = colors, s = sizes , alpha = .7, cmap = 'viridis', edgecolors = 'black')

plt.title('Random Scatter Plot')
plt.xlabel('x values')
plt.ylabel('y values')

plt.colorbar()

plt.show()

# %%
data=pd.read_csv('concrete.csv')
data
# Out:
#       cement   slag    ash  water  superplasticizer  coarseagg  fineagg  age  \
# 0      141.3  212.0    0.0  203.5               0.0      971.8    748.5   28
# 1      168.9   42.2  124.3  158.3              10.8     1080.8    796.2   14
# 2      250.0    0.0   95.7  187.4               5.5      956.9    861.2   28
# 3      266.0  114.0    0.0  228.0               0.0      932.0    670.0   28
# 4      154.8  183.4    0.0  193.3               9.1     1047.4    696.7   28
# ...      ...    ...    ...    ...               ...        ...      ...  ...
# 1025   135.0    0.0  166.0  180.0              10.0      961.0    805.0   28
# 1026   531.3    0.0    0.0  141.8              28.2      852.1    893.7    3
# 1027   276.4  116.0   90.3  179.6               8.9      870.1    768.3   28
# 1028   342.0   38.0    0.0  228.0               0.0      932.0    670.0  270
# 1029   540.0    0.0    0.0  173.0               0.0     1125.0    613.0    7
#
#       strength
# 0        29.89
# ...

# %%
s=data['strength']
w=data['water']
c=data['cement']

# %%
plt.figure(figsize=(20,10))
plt.scatter(s,c,s=w,c=s,alpha=0.7,cmap='rainbow_r',edgecolors='black')
plt.colorbar()
plt.show()

# %%
x=np.random.randn(10000)
plt.style.use('Solarize_Light2')
plt.hist(x,edgecolor='black')
plt.show()

# %%
x=np.random.randn(10000)
plt.style.use('Solarize_Light2')
plt.hist(x,bins=30,color='magenta',edgecolor='red')
plt.title('Normal Distribution ')
plt.xlabel('values')
plt.ylabel('Freq')
plt.show()

# %%
x=np.random.randn(100000)
plt.style.use('Solarize_Light2')
plt.hist(x,bins=1000,color='navy',edgecolor='red')
plt.title('Normal Distribution ')
plt.xlabel('values')
plt.ylabel('Freq')
plt.show()

# %%
x=np.random.randn(100000)
plt.style.use('Solarize_Light2')
plt.hist(x,bins=30,color='navy',edgecolor='red',histtype='stepfilled',alpha=0.8)
plt.title('Normal Distribution ')
plt.xlabel('values')
plt.ylabel('Freq')
plt.show()

# %%
x1=np.random.randn(100000)
x2=np.random.randn(100000)+2
x3=np.random.randn(100000)+4

plt.style.use('Solarize_Light2')
plt.hist(x1,bins=30,edgecolor='black',alpha=0.7)
plt.hist(x2,bins=30,edgecolor='black',alpha=0.7)
plt.hist(x3,bins=30,edgecolor='black',alpha=0.7)
plt.title('Normal Distribution ')
plt.xlabel('values')
plt.ylabel('Freq')
plt.show()

# %% [markdown]
# 2D histogram

# %%
x=np.random.randn(1000)
y=np.random.randn(1000)
plt.hist2d(x,y,bins=30,cmap='twilight')
plt.title('2D histogram')
plt.show()

# %%
x=np.random.randn(1000)
y=np.random.randn(1000)
plt.hist2d(x,y,bins=30,cmap='cividis')
plt.colorbar()
plt.title('2D histogram')
plt.show()

# %%
twoDhist=plt.figure()
twoDhist.savefig('fig.png')

# %%
cars=["Audi","BMW","Tesla","Ford","Toyata","Mercedese"]
data=[260,350,30,400,650,320]
explode=[0,0,0.3,0,0,0]
plt.figure(figsize=(7,7))
plt.pie(data,labels=cars,shadow=True,explode=explode,autopct='%2.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x155ffae90>,
# ...
#  [Text(1.0104156458289228, 0.4348105595131298, 'Audi'),
#   Text(0.2303842507146314, 1.0756035966017676, 'BMW'),
#   Text(-0.5268328293518242, 1.307878881975373, 'Tesla'),
#   Text(-0.9568970304514411, 0.5425385452787791, 'Ford'),
#   Text(-0.47395004669610336, -0.9926587294920454, 'Toyata'),
#   Text(0.9652596095729276, -0.5275167164432988, 'Mercedese')],
#  [Text(0.551135806815776, 0.23716939609807078, '12.94%'),
#   Text(0.1256641367534353, 0.5866928708736914, '17.41%'),
#   Text(-0.3400126770994042, 0.8440920443954535, '1.49%'),
#   Text(-0.5219438347916951, 0.29593011560660676, '19.90%'),
#   Text(-0.2585182072887836, -0.5414502160865702, '32.34%'),
#   Text(0.5265052415852332, -0.2877363907872539, '15.92%')])

# %%
cars=["Audi","BMW","Tesla","Ford","Toyata","Mercedese"]
data=[260,350,30,400,650,320]
explode=[0,0,0.3,0,0,0]
plt.figure(figsize=(7,7))
plt.pie(data,labels=cars,explode=explode,autopct='%2.2f%%',wedgeprops={'edgecolor':'black','antialiased' : True})
# Out:
# ([<matplotlib.patches.Wedge at 0x280e73f90>,
# ...
#  [Text(1.0104156458289228, 0.4348105595131298, 'Audi'),
#   Text(0.2303842507146314, 1.0756035966017676, 'BMW'),
#   Text(-0.5230964263067758, 1.2986031452237747, 'Tesla'),
#   Text(-0.9568970304514411, 0.5425385452787791, 'Ford'),
#   Text(-0.47395004669610336, -0.9926587294920454, 'Toyata'),
#   Text(0.9652596095729276, -0.5275167164432988, 'Mercedese')],
#  [Text(0.551135806815776, 0.23716939609807078, '12.94%'),
#   Text(0.1256641367534353, 0.5866928708736914, '17.41%'),
#   Text(-0.33627627405435584, 0.8348163076438551, '1.49%'),
#   Text(-0.5219438347916951, 0.29593011560660676, '19.90%'),
#   Text(-0.2585182072887836, -0.5414502160865702, '32.34%'),
#   Text(0.5265052415852332, -0.2877363907872539, '15.92%')])

# %% [markdown]
# 3D plot

# %%
ax=plt.axes(projection='3d')
z=np.linspace(1,10,1000)
x=np.cos(z)
y=np.sin(z)
ax.plot3D(x,y,z)

# %%
from mpl_toolkits.mplot3d import Axes3D
fig=plt.figure()
ax=fig.add_subplot(111,projection='3d')
x = np.random.rand(100)
y = np.random.rand(100)
z = np.random.rand(100)

ax.scatter(x,y,z, c = 'blue', marker = '*')

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

plt.tight_layout()

plt.show()
